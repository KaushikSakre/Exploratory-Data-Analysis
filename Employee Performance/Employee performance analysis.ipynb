# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hr = pd.read_csv('HR-Employee-Attrition.csv')

# %%
hr.sample(5)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 998    26        No      Travel_Rarely        683  Research & Development
# 929    28        No  Travel_Frequently        193  Research & Development
# 1280   37        No      Travel_Rarely       1239         Human Resources
# 569    36        No         Non-Travel       1434                   Sales
# 377    36        No      Travel_Rarely        329  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 998                  2          1        Medical              1
# 929                  2          3  Life Sciences              1
# 1280                 8          2          Other              1
# 569                  8          4  Life Sciences              1
# 377                  2          3  Life Sciences              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
hr.shape
# Out:
# (1470, 35)

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
hr.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#Label column --> Attrition
# no means employ didn't leave the company 
hr['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
sns.countplot(hr['Attrition'])
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
#AGE

# %%
sns.distplot(hr['Age'])
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
hr['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
##we will handle categorical column later
hr['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
sns.countplot(hr['BusinessTravel'])
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %%
hr['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
sns.countplot(hr['Department'])
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
hr['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
sns.countplot(hr['EducationField'])
plt.xticks(rotation=45)
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Life Sciences'),
#   Text(1, 0, 'Other'),
#   Text(2, 0, 'Medical'),
#   Text(3, 0, 'Marketing'),
#   Text(4, 0, 'Technical Degree'),
#   Text(5, 0, 'Human Resources')])

# %%
sns.distplot(hr['Age'],hist=False)
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(hr['MonthlyIncome'],hist=False)
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Density'>

# %%
sns.boxplot(hr['Age'])
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
sns.distplot(hr[hr['Attrition']=='No']['Age'],hist=False)
sns.distplot(hr[hr['Attrition']=='Yes']['Age'],hist=False)
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
'''
RelationshipSatisfaction
1 'Low'
2 'Medium'
3 'High'
4 'Very High'
'''
(hr['RelationshipSatisfaction'].value_counts()).plot(kind='pie',autopct='%2.2f%%')
# Out:
# <AxesSubplot:ylabel='RelationshipSatisfaction'>

# %%
'''
1 'Below College'
2 'College'
3 'Bachelor'
4 'Master'
5 'Doctor'
'''

(hr['Education'].value_counts()).plot(kind='pie',autopct='%2.2f%%')
# Out:
# <AxesSubplot:ylabel='Education'>

# %%
'''
WorkLifeBalance
1 'Bad'
2 'Good'
3 'Better'
4 'Best'
'''
(hr['WorkLifeBalance'].value_counts()).plot(kind='pie',autopct='%2.2f%%')
# Out:
# <AxesSubplot:ylabel='WorkLifeBalance'>

# %%
sns.distplot(hr['WorkLifeBalance'])
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='WorkLifeBalance', ylabel='Density'>

# %%
hr['OverTime'].value_counts()
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %%
sns.countplot(hr['OverTime'])
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %%
(hr['OverTime'].value_counts()).plot(kind='pie',autopct='%2.2f%%')
# Out:
# <AxesSubplot:ylabel='OverTime'>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(hr['Age'],hr['MonthlyIncome'],hue = hr['EducationField'])
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='MonthlyIncome'>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(hr['Age'],hr['MonthlyIncome'],hue=hr['JobRole'])
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='MonthlyIncome'>

# %%
sns.distplot(hr[hr['BusinessTravel']=='Travel_Rarely']['MonthlyIncome'],hist=False)
sns.distplot(hr[hr['BusinessTravel']=='Travel_Frequently']['MonthlyIncome'],hist=False)
sns.distplot(hr[hr['BusinessTravel']=='Non-Travel']['MonthlyIncome'],hist=False)
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
hr['JobLevel'].unique()
# Out:
# array([2, 1, 3, 4, 5], dtype=int64)

# %%
hr.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#hr.groupby(by='JobRole')

# %%
hr['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
plt.figure(figsize=(10,10))
sns.boxplot(hr['Department'],hr['Age'],hue=hr['MaritalStatus'])
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Department', ylabel='Age'>

# %%
sns.boxplot(hr['Gender'],hr['Age'],hue=hr['Department'])
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %%
sns.boxplot(hr['Gender'],hr['Age'],hue=hr['BusinessTravel'])
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %%
plt.figure(figsize=(10,10))
sns.boxplot(hr['Department'],hr['MonthlyIncome'],hue=hr['MaritalStatus'])
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Department', ylabel='MonthlyIncome'>

# %%
plt.figure(figsize=(10,10))
sns.boxplot(hr['Department'],hr['MonthlyIncome'],hue=hr['Gender'])
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Department', ylabel='MonthlyIncome'>

# %%
plt.figure(figsize=(10,10))
sns.boxplot(hr['EducationField'],hr['MonthlyIncome'],hue=hr['Gender'])
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EducationField', ylabel='MonthlyIncome'>

# %%
plt.figure(figsize=(10,10))
sns.boxplot(hr['EducationField'],hr['MonthlyIncome'],hue=hr['OverTime'])
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EducationField', ylabel='MonthlyIncome'>

# %%
plt.subplots(figsize=(18,18))
sns.heatmap(hr.corr(),annot=True,linewidths=0.5,linecolor="green",fmt=".1f")
plt.show()

# %%
sns.barplot(x='JobLevel',y='MonthlyIncome',data=hr)
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='MonthlyIncome'>

# %%
sns.scatterplot(x='TotalWorkingYears',y='MonthlyIncome',data=hr)
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='MonthlyIncome'>

# %%
sns.scatterplot(x='Age',y='TotalWorkingYears',data=hr)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='TotalWorkingYears'>

# %%
sns.distplot(hr['PercentSalaryHike'])
# Out:
# C:\Users\Kaushik sakre\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='Density'>

# %%
sns.histplot(hr['PercentSalaryHike'])
# Out:
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='Count'>

# %%
sns.scatterplot(x='JobLevel',y='MonthlyIncome',data=hr)
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='MonthlyIncome'>

# %%
hr.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
num_cols = hr._get_numeric_data().columns
  
cate_cols = list(set(hr.columns)-set(num_cols))

# %%
hr.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
hr.drop(columns=['Over18','DailyRate','HourlyRate','MonthlyRate','StandardHours','EmployeeCount','EmployeeNumber',
                 'DistanceFromHome','StockOptionLevel','PerformanceRating','EnvironmentSatisfaction'],inplace=True)

# %%
hr.shape
# Out:
# (1470, 24)

# %%
plt.subplots(figsize=(18,18))
sns.heatmap(hr.corr(method='pearson'),annot=True,linewidths=0.5,linecolor="green",fmt=".1f")
plt.show()

# %%
from sklearn import model_selection



X = hr.drop(columns=['Attrition'])
Y = hr['Attrition']

print(X.shape)
print(Y.shape)
/
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y, random_state = 42,test_size=0.33)
X_train.shape, X_test.shape, type(X_train)
# Out:
# (1470, 23)
# (1470,)
# ((984, 23), (486, 23), pandas.core.frame.DataFrame)

# %%
from sklearn.feature_selection import SelectKBest
sel_cols = SelectKBest(hr.corr(),k=12)

# %%
num_cols = hr._get_numeric_data().columns
  
cate_cols = list(set(hr.columns)-set(num_cols))

# %%
cate_cols
# Out:
# ['OverTime',
#  'Gender',
#  'MaritalStatus',
#  'JobRole',
#  'EducationField',
#  'Attrition',
#  'BusinessTravel',
#  'Department']

# %%
hr['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.compose import ColumnTransformer

transformer = ColumnTransformer(transformers=[
    ('tnf2',OrdinalEncoder(categories=[['Travel_Rarely', 'Travel_Frequently', 'Non-Travel']]),['BusinessTravel']),
    ('tnf3',OneHotEncoder(sparse_output=False,drop='first'),['Gender','MaritalStatus','Department','OverTime','JobRole','EducationField'])
],remainder='passthrough')

# %%
X_train=transformer.fit_transform(X_train)

# %%
X_test=transformer.transform(X_test)

# %%
le = LabelEncoder()

# %%
le.fit(y_train)
y_train = le.transform(y_train)
y_test = le.transform(y_test)

# %%
from sklearn.ensemble import RandomForestClassifier
rgclf = RandomForestClassifier(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

# %%
rgclf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=15, max_features=0.75, max_samples=0.5,
#                        random_state=3)

# %%
y_pred = rgclf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8621399176954733

# %%
rgclf.feature_importances_
# Out:
# array([0.01629819, 0.01135132, 0.00838106, 0.04277143, 0.00908326,
#        0.00673015, 0.07929663, 0.00443832, 0.01266018, 0.00090832,
#        0.00506137, 0.0010738 , 0.00987835, 0.00881817, 0.00899688,
#        0.01025364, 0.00903752, 0.00889627, 0.00640309, 0.00993825,
#        0.091029  , 0.02564512, 0.03448108, 0.01481585, 0.03319173,
#        0.12326375, 0.0571665 , 0.04520658, 0.03466985, 0.06465877,
#        0.03882524, 0.02355883, 0.04665022, 0.03292593, 0.02745468,
#        0.0361807 ])
